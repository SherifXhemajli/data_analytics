# %% [markdown]
# # Importing and preparing restaurant data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import re
import time
import fnmatch
import numpy as np
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/1_AT_Scraping

# %% [markdown]
# ## Importing data

# %%
# Show .csv - files in the directory
flist = fnmatch.filter(os.listdir('.'), '*.csv')
for i in flist:
    print(i)

# Read the data to a pandas data frame
df = pd.read_csv('restaurant_data_zuerich.csv', sep=',', encoding='utf-8')

# Show first records of data frame
df.head()
# Out:
# restaurant_data_zuerich.csv
# restaurant_data_zuerich_prepared.csv
#   web-scraper-order                              web-scraper-start-url  \
# 0      1705095756-1  https://de.yelp.ch/search?find_desc=Restaurant...
# 1      1705095762-2  https://de.yelp.ch/search?find_desc=Restaurant...
# 2      1705095768-3  https://de.yelp.ch/search?find_desc=Restaurant...
# 3      1705095776-4  https://de.yelp.ch/search?find_desc=Restaurant...
# 4      1705095781-5  https://de.yelp.ch/search?find_desc=Restaurant...
#
#         detail_link                                   detail_link-href  \
# 0    White Elephant  https://de.yelp.ch/biz/white-elephant-z%C3%BCr...
# 1        Bamboo Inn  https://de.yelp.ch/biz/bamboo-inn-z%C3%BCrich?...
# 2  Restaurant Luca²  https://de.yelp.ch/biz/restaurant-luca%C2%B2-z...
# 3           L’Altro  https://de.yelp.ch/biz/l-altro-z%C3%BCrich?osq...
# 4              ROSI  https://de.yelp.ch/biz/rosi-z%C3%BCrich?osq=Re...
#
#     restaurant_name  total_stars number_of_reviews      cuisine_type  \
# 0    White Elephant          4.3      (30 reviews)      Thailändisch
# 1        Bamboo Inn          4.0       (2 reviews)        Chinesisch
# 2  Restaurant Luca²          4.7       (6 reviews)        Mediterran
# 3           L'Altro          5.0       (7 reviews)       Italienisch
# 4              ROSI          4.0       (2 reviews)  Bayerische Küche
#
#   price_class                                    raw_description  \
# 0         $$$  The White Elephant restaurant has the reputati...
# 1         NaN                                                NaN
# 2         $$$                 Mediterrane Küche, besondere Weine
# 3         $$$                                                NaN
# 4         NaN                                                NaN
#
#                                        opening_times  \
# 0             12:00 PM - 2:00 PM, 6:00 PM - 10:00 PM
# 1             11:30 AM - 2:00 PM, 6:00 PM - 10:00 PM
# 2             11:30 AM - 2:00 PM, 6:30 PM - 11:45 PM
# 3  11:30 AM - 2:30 PM, 5:30 PM - 12:00 AM (Folgetag)
# 4                      6:00 PM - 12:00 AM (Folgetag)
#
#                            adress district  \
# 0     Neumühlequai 42 8006 Zürich  Kreis 6
# 1   Culmannstrasse 19 8006 Zürich  Kreis 6
# 2      Asylstrasse 81 8032 Zürich  Kreis 7
# 3   Sternenstrasse 11 8002 Zürich  Kreis 2
# 4  Sihlfeldstrasse 89 8004 Zürich  Kreis 4
#
#                                             long_lat  \
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...
#
#                                        all_amenities
# 0  Reservationen möglichBestellung zum AbholenKei...
# 1  Lieferung möglichBestellung zum AbholenFür Kin...
# 2  Reservationen möglichKein LieferserviceKeine M...
# 3  Reservationen möglichKeine MitnahmeSitzplätze ...
# 4                                                NaN

# %% [markdown]
# ## Count number of rows and columns in the data frame

# %%
# Dimension (rows, columns)
print('Dimension:', df.shape)

# Number of rows
print('Number of rows:', df.shape[0])

# Number of columns
print('Number of columns:', df.shape[1])
# Out:
# Dimension: (235, 15)
# Number of rows: 235
# Number of columns: 15

# %% [markdown]
# ### Extract longtitude & latitude of restaurants (Regex)

# %%
#lat

lat = []
for i in df['long_lat']:
    d1 = re.findall('center=([-\d.]+)%2C[-\d.]+', i)
    try:
        d2 = d1[0].strip()
    except IndexError:
        d2 = None
    lat.append(d2)

# Save as new variable in the pandas data frame
df['lat'] = pd.Series(lat, dtype="float")

# Print first 5 values
print(df['long_lat'].head(5), '\n')
print(df['lat'].head(5))

#long

long = []
for i in df['long_lat']:
    d1 = re.findall(r'center=[-\d.]+%2C([-\d.]+)', i)
    try:
        d2 = d1[0].strip()
    except IndexError:
        d2 = None
    long.append(d2)

# Save as new variable in the pandas data frame
df['long'] = pd.Series(long, dtype="float")

# Print first 5 values
print(df['long_lat'].head(5), '\n')
print(df['long'].head(5))

df.head(5)
# Out:
# 0    https://maps.googleapis.com/maps/api/staticmap...
# 1    https://maps.googleapis.com/maps/api/staticmap...
# 2    https://maps.googleapis.com/maps/api/staticmap...
# 3    https://maps.googleapis.com/maps/api/staticmap...
# 4    https://maps.googleapis.com/maps/api/staticmap...
# Name: long_lat, dtype: object
#
# 0    47.382439
# 1    47.380480
# 2    47.366809
# 3    47.360064
# 4    47.376481
# Name: lat, dtype: float64
# 0    https://maps.googleapis.com/maps/api/staticmap...
# 1    https://maps.googleapis.com/maps/api/staticmap...
# 2    https://maps.googleapis.com/maps/api/staticmap...
# 3    https://maps.googleapis.com/maps/api/staticmap...
# 4    https://maps.googleapis.com/maps/api/staticmap...
# Name: long_lat, dtype: object
#
# 0    8.540643
# 1    8.547261
# 2    8.561675
# 3    8.534062
# 4    8.516238
# Name: long, dtype: float64
#   web-scraper-order                              web-scraper-start-url  \
# 0      1705095756-1  https://de.yelp.ch/search?find_desc=Restaurant...
# 1      1705095762-2  https://de.yelp.ch/search?find_desc=Restaurant...
# 2      1705095768-3  https://de.yelp.ch/search?find_desc=Restaurant...
# 3      1705095776-4  https://de.yelp.ch/search?find_desc=Restaurant...
# 4      1705095781-5  https://de.yelp.ch/search?find_desc=Restaurant...
#
#         detail_link                                   detail_link-href  \
# 0    White Elephant  https://de.yelp.ch/biz/white-elephant-z%C3%BCr...
# 1        Bamboo Inn  https://de.yelp.ch/biz/bamboo-inn-z%C3%BCrich?...
# 2  Restaurant Luca²  https://de.yelp.ch/biz/restaurant-luca%C2%B2-z...
# 3           L’Altro  https://de.yelp.ch/biz/l-altro-z%C3%BCrich?osq...
# 4              ROSI  https://de.yelp.ch/biz/rosi-z%C3%BCrich?osq=Re...
#
#     restaurant_name  total_stars number_of_reviews      cuisine_type  \
# 0    White Elephant          4.3      (30 reviews)      Thailändisch
# 1        Bamboo Inn          4.0       (2 reviews)        Chinesisch
# 2  Restaurant Luca²          4.7       (6 reviews)        Mediterran
# 3           L'Altro          5.0       (7 reviews)       Italienisch
# 4              ROSI          4.0       (2 reviews)  Bayerische Küche
#
#   price_class                                    raw_description  \
# 0         $$$  The White Elephant restaurant has the reputati...
# 1         NaN                                                NaN
# 2         $$$                 Mediterrane Küche, besondere Weine
# 3         $$$                                                NaN
# 4         NaN                                                NaN
#
#                                        opening_times  \
# 0             12:00 PM - 2:00 PM, 6:00 PM - 10:00 PM
# 1             11:30 AM - 2:00 PM, 6:00 PM - 10:00 PM
# 2             11:30 AM - 2:00 PM, 6:30 PM - 11:45 PM
# 3  11:30 AM - 2:30 PM, 5:30 PM - 12:00 AM (Folgetag)
# 4                      6:00 PM - 12:00 AM (Folgetag)
#
#                            adress district  \
# 0     Neumühlequai 42 8006 Zürich  Kreis 6
# 1   Culmannstrasse 19 8006 Zürich  Kreis 6
# 2      Asylstrasse 81 8032 Zürich  Kreis 7
# 3   Sternenstrasse 11 8002 Zürich  Kreis 2
# 4  Sihlfeldstrasse 89 8004 Zürich  Kreis 4
#
#                                             long_lat  \
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...
#
#                                        all_amenities        lat      long
# 0  Reservationen möglichBestellung zum AbholenKei...  47.382439  8.540643
# 1  Lieferung möglichBestellung zum AbholenFür Kin...  47.380480  8.547261
# 2  Reservationen möglichKein LieferserviceKeine M...  47.366809  8.561675
# 3  Reservationen möglichKeine MitnahmeSitzplätze ...  47.360064  8.534062
# 4                                                NaN  47.376481  8.516238

# %% [markdown]
# ### Convert the amenities in to a numeric value ( yes = 1, no = 0, NaN = information missing)

# %%
# All current amenities are as a single string in the csv file
common_amenities = [
    ("Reservationen möglich", "Keine Reservationen"),
    ("Lieferung möglich", "Kein Lieferservice"),
    ("Sitzplätze im Freien", "Keine Sitzplätze im Freien"),
    ("Für Kinder geeignet", "Nicht für Kinder geeignet"),
    ("Für Gruppen geeignet", "Nicht für Gruppen geeignet"),
    ("TV", "Kein TV")
]

def check_amenities_presence(amenities, amenity_pairs):
    if not isinstance(amenities, (list, str)): 
        return {} 
    results = {}
    for positive, negative in amenity_pairs:
        if positive in amenities:
            results[positive] = 1
        elif negative in amenities:
            results[positive] = 0
        else:
            results[positive] = None
    return results

# Applying the function to the dataset and updating the DataFrame
for amenity_pair in common_amenities:
    positive_amenity = amenity_pair[0]
    # Create a new column for each positive amenity
    df[positive_amenity] = df['all_amenities'].apply(lambda x: check_amenities_presence(x, [amenity_pair]).get(positive_amenity))


#rename columns

df.rename(columns={'Reservationen möglich': 'takes_reservations', 'Lieferung möglich': 'delivery', 'Sitzplätze im Freien': 'outdoor_seating', 'Für Kinder geeignet': 'good_for_kids', 'Für Gruppen geeignet':'good_for_groups', 'TV': 'tv', 'adress':'address'}, inplace=True)

# Displaying the first few rows of the updated DataFrame
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1705095756-1  https://de.yelp.ch/search?find_desc=Restaurant...
# 1      1705095762-2  https://de.yelp.ch/search?find_desc=Restaurant...
# 2      1705095768-3  https://de.yelp.ch/search?find_desc=Restaurant...
# 3      1705095776-4  https://de.yelp.ch/search?find_desc=Restaurant...
# 4      1705095781-5  https://de.yelp.ch/search?find_desc=Restaurant...
#
#         detail_link                                   detail_link-href  \
# 0    White Elephant  https://de.yelp.ch/biz/white-elephant-z%C3%BCr...
# 1        Bamboo Inn  https://de.yelp.ch/biz/bamboo-inn-z%C3%BCrich?...
# 2  Restaurant Luca²  https://de.yelp.ch/biz/restaurant-luca%C2%B2-z...
# 3           L’Altro  https://de.yelp.ch/biz/l-altro-z%C3%BCrich?osq...
# 4              ROSI  https://de.yelp.ch/biz/rosi-z%C3%BCrich?osq=Re...
#
#     restaurant_name  total_stars number_of_reviews      cuisine_type  \
# 0    White Elephant          4.3      (30 reviews)      Thailändisch
# 1        Bamboo Inn          4.0       (2 reviews)        Chinesisch
# 2  Restaurant Luca²          4.7       (6 reviews)        Mediterran
# 3           L'Altro          5.0       (7 reviews)       Italienisch
# 4              ROSI          4.0       (2 reviews)  Bayerische Küche
#
#   price_class                                    raw_description  ...  \
# 0         $$$  The White Elephant restaurant has the reputati...  ...
# 1         NaN                                                NaN  ...
# 2         $$$                 Mediterrane Küche, besondere Weine  ...
# 3         $$$                                                NaN  ...
# 4         NaN                                                NaN  ...
#
#                                             long_lat  \
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...
#
#                                        all_amenities        lat      long  \
# 0  Reservationen möglichBestellung zum AbholenKei...  47.382439  8.540643
# 1  Lieferung möglichBestellung zum AbholenFür Kin...  47.380480  8.547261
# 2  Reservationen möglichKein LieferserviceKeine M...  47.366809  8.561675
# 3  Reservationen möglichKeine MitnahmeSitzplätze ...  47.360064  8.534062
# 4                                                NaN  47.376481  8.516238
#
#   takes_reservations  delivery  outdoor_seating  good_for_kids  \
# 0                1.0       0.0              1.0            1.0
# 1                NaN       1.0              NaN            1.0
# 2                1.0       0.0              1.0            0.0
# 3                1.0       NaN              1.0            1.0
# 4                NaN       NaN              NaN            NaN
#
#    good_for_groups   tv
# 0              1.0  1.0
# 1              NaN  NaN
# 2              1.0  1.0
# 3              1.0  NaN
# 4              NaN  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Convert the price class in to a numeric value ( $ = 1)

# %%
def convert_dollar_to_number(dollar_str):
    if pd.isna(dollar_str):
        return None
    return len(dollar_str)

# Applying the conversion function to the 'price_class' column
df['price_class'] = df['price_class'].apply(convert_dollar_to_number)

df.head(5)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1705095756-1  https://de.yelp.ch/search?find_desc=Restaurant...
# 1      1705095762-2  https://de.yelp.ch/search?find_desc=Restaurant...
# 2      1705095768-3  https://de.yelp.ch/search?find_desc=Restaurant...
# 3      1705095776-4  https://de.yelp.ch/search?find_desc=Restaurant...
# 4      1705095781-5  https://de.yelp.ch/search?find_desc=Restaurant...
#
#         detail_link                                   detail_link-href  \
# 0    White Elephant  https://de.yelp.ch/biz/white-elephant-z%C3%BCr...
# 1        Bamboo Inn  https://de.yelp.ch/biz/bamboo-inn-z%C3%BCrich?...
# 2  Restaurant Luca²  https://de.yelp.ch/biz/restaurant-luca%C2%B2-z...
# 3           L’Altro  https://de.yelp.ch/biz/l-altro-z%C3%BCrich?osq...
# 4              ROSI  https://de.yelp.ch/biz/rosi-z%C3%BCrich?osq=Re...
#
#     restaurant_name  total_stars number_of_reviews      cuisine_type  \
# 0    White Elephant          4.3      (30 reviews)      Thailändisch
# 1        Bamboo Inn          4.0       (2 reviews)        Chinesisch
# 2  Restaurant Luca²          4.7       (6 reviews)        Mediterran
# 3           L'Altro          5.0       (7 reviews)       Italienisch
# 4              ROSI          4.0       (2 reviews)  Bayerische Küche
#
#    price_class                                    raw_description  ...  \
# 0          3.0  The White Elephant restaurant has the reputati...  ...
# 1          NaN                                                NaN  ...
# 2          3.0                 Mediterrane Küche, besondere Weine  ...
# 3          3.0                                                NaN  ...
# 4          NaN                                                NaN  ...
#
#                                             long_lat  \
# 0  https://maps.googleapis.com/maps/api/staticmap...
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 2  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...
#
#                                        all_amenities        lat      long  \
# 0  Reservationen möglichBestellung zum AbholenKei...  47.382439  8.540643
# 1  Lieferung möglichBestellung zum AbholenFür Kin...  47.380480  8.547261
# 2  Reservationen möglichKein LieferserviceKeine M...  47.366809  8.561675
# 3  Reservationen möglichKeine MitnahmeSitzplätze ...  47.360064  8.534062
# 4                                                NaN  47.376481  8.516238
#
#   takes_reservations  delivery  outdoor_seating  good_for_kids  \
# 0                1.0       0.0              1.0            1.0
# 1                NaN       1.0              NaN            1.0
# 2                1.0       0.0              1.0            0.0
# 3                1.0       NaN              1.0            1.0
# 4                NaN       NaN              NaN            NaN
#
#    good_for_groups   tv
# 0              1.0  1.0
# 1              NaN  NaN
# 2              1.0  1.0
# 3              1.0  NaN
# 4              NaN  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Count and identify missing values (if any)

# %%
# Count missing values
print(pd.isna(df).sum())

# Identify rows with missing values
df[df.isna().any(axis=1)].head()
# Out:
# web-scraper-order          0
# web-scraper-start-url      0
# detail_link                0
# detail_link-href           0
# restaurant_name            0
# total_stars                0
# number_of_reviews          0
# cuisine_type               0
# price_class               72
# raw_description          176
# opening_times             25
# address                    5
# district                  13
# long_lat                   0
# all_amenities             28
# lat                        0
# long                       0
# takes_reservations        84
# delivery                  79
# outdoor_seating           72
# good_for_kids             73
# good_for_groups           68
# tv                        81
# dtype: int64
#   web-scraper-order                              web-scraper-start-url  \
# 1      1705095762-2  https://de.yelp.ch/search?find_desc=Restaurant...
# 3      1705095776-4  https://de.yelp.ch/search?find_desc=Restaurant...
# 4      1705095781-5  https://de.yelp.ch/search?find_desc=Restaurant...
# 5      1705095787-6  https://de.yelp.ch/search?find_desc=Restaurant...
# 6      1705095793-7  https://de.yelp.ch/search?find_desc=Restaurant...
#
#   detail_link                                   detail_link-href  \
# 1  Bamboo Inn  https://de.yelp.ch/biz/bamboo-inn-z%C3%BCrich?...
# 3     L’Altro  https://de.yelp.ch/biz/l-altro-z%C3%BCrich?osq...
# 4        ROSI  https://de.yelp.ch/biz/rosi-z%C3%BCrich?osq=Re...
# 5       Ototo  https://de.yelp.ch/biz/ototo-z%C3%BCrich?osq=R...
# 6     Chimy’s  https://de.yelp.ch/biz/chimy-s-z%C3%BCrich?osq...
#
#   restaurant_name  total_stars number_of_reviews      cuisine_type  \
# 1      Bamboo Inn          4.0       (2 reviews)        Chinesisch
# 3         L'Altro          5.0       (7 reviews)       Italienisch
# 4            ROSI          4.0       (2 reviews)  Bayerische Küche
# 5           Ototo          4.3       (7 reviews)             Sushi
# 6         Chimy’s          4.7       (3 reviews)       Vegetarisch
#
#    price_class raw_description  ...  \
# 1          NaN             NaN  ...
# 3          3.0             NaN  ...
# 4          NaN             NaN  ...
# 5          3.0             NaN  ...
# 6          NaN             NaN  ...
#
#                                             long_lat  \
# 1  https://maps.googleapis.com/maps/api/staticmap...
# 3  https://maps.googleapis.com/maps/api/staticmap...
# 4  https://maps.googleapis.com/maps/api/staticmap...
# 5  https://maps.googleapis.com/maps/api/staticmap...
# 6  https://maps.googleapis.com/maps/api/staticmap...
#
#                                        all_amenities        lat      long  \
# 1  Lieferung möglichBestellung zum AbholenFür Kin...  47.380480  8.547261
# 3  Reservationen möglichKeine MitnahmeSitzplätze ...  47.360064  8.534062
# 4                                                NaN  47.376481  8.516238
# 5  Reservationen möglichLieferung möglichBestellu...  47.392527  8.530738
# 6                                                 TV  47.383290  8.528432
#
#   takes_reservations  delivery  outdoor_seating  good_for_kids  \
# 1                NaN       1.0              NaN            1.0
# 3                1.0       NaN              1.0            1.0
# 4                NaN       NaN              NaN            NaN
# 5                1.0       1.0              1.0            1.0
# 6                NaN       NaN              NaN            NaN
#
#    good_for_groups   tv
# 1              NaN  NaN
# 3              1.0  NaN
# 4              NaN  NaN
# 5              1.0  1.0
# 6              NaN  1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Remove the restaurants with no amenitie info

# %%
df = df.dropna(subset=['all_amenities'])

# Dimension (rows, columns)
print('Dimension:', df.shape)

# Number of rows
print('Number of rows:', df.shape[0])

# Number of columns
print('Number of columns:', df.shape[1])
# Out:
# Dimension: (207, 23)
# Number of rows: 207
# Number of columns: 23

# %% [markdown]
# ## Count and identify duplicated values (if any)

# %%
# Count duplicated values
print(df.duplicated().sum())

# Identify rows with duplicated values, e.g.:
df[df[['web-scraper-order', 'restaurant_name', 'address']].duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [web-scraper-order, web-scraper-start-url, detail_link, detail_link-href, restaurant_name, total_stars, number_of_reviews, cuisine_type, price_class, raw_description, opening_times, address, district, long_lat, all_amenities, lat, long, takes_reservations, delivery, outdoor_seating, good_for_kids, good_for_groups, tv]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### Save data to file

# %%
df.to_csv('restaurant_data_zuerich_prepared.csv', 
          sep=",", 
          encoding='utf-8',
          index=False)
